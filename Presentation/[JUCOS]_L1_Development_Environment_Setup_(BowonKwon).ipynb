# %% [markdown]
# # [1강] 개발환경 구축
# &nbsp;&nbsp;&nbsp;&nbsp;JUCOS 240513
# &nbsp;&nbsp;&nbsp;&nbsp;Bowon Kwon

# %% [markdown]
# 📝 **'왜 PyTorch로 공부하는가'**는 📄제안서와 📄설문조사서로 갈음합니다.
#
# </br>
#
# 🚨 **(유의사항)** 앞으로 코딩에 쓰는
# &emsp;✔&nbsp;&nbsp;💻 **OS 계정 이름**(Windows 비밀번호를 입력하는 첫 화면에 뜨는 이름)
# &emsp;✔&nbsp;&nbsp;📁 **폴더 이름**
# &emsp;✔&nbsp;&nbsp;💾 **파일 이름**은
#
# &emsp;➜&nbsp;&nbsp;**영문**으로,
# &emsp;➜&nbsp;&nbsp;**띄어쓰기 없이** 쓰는 것이 좋습니다!
#
# &emsp;🚫&nbsp;&nbsp;**즉, 작업할 폴더와 파일까지 이르는 경로 전체에 ❌ 한글을 쓰거나, ❌ 띄어 쓰지 말 것!**
# &emsp;&emsp;&ensp;(띄어쓰기가 꼭 필요하다면 **언더바_** 사용)
# &emsp;👌&nbsp;&nbsp;**OS 계정 이름 변경**이 어렵다면 **새 계정을 생성**해도 됩니다~
# &emsp;&emsp;&ensp;(계정 생성 방법: [MS 고객 지원 사이트](https://support.microsoft.com/ko-kr/windows/windows%EC%97%90%EC%84%9C-%EB%A1%9C%EC%BB%AC-%EC%82%AC%EC%9A%A9%EC%9E%90-%EB%98%90%EB%8A%94-%EA%B4%80%EB%A6%AC%EC%9E%90-%EA%B3%84%EC%A0%95-%EB%A7%8C%EB%93%A4%EA%B8%B0-20de74e0-ac7f-3502-a866-32915af2a34d))

# %% [markdown]
# ### (참고) 2024년 5월 현재, Python의 위상

# %% [markdown]
# #### TIOBE Index for May 2024
# https://www.tiobe.com/tiobe-index/

# %% [markdown]
# (참고) 프로그래밍잡부, ["TIOBE 프로그래밍 언어 순위를 믿지 마라 - 프로그래밍 언어 선택 가이드"](https://kdw9502.tistory.com/7) (2019. 12. 10.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### PYPL PopularitY of Programming Language
# https://pypl.github.io/PYPL.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### IEEE Spectrum, The Top Programming Languages 2023
# https://spectrum.ieee.org/the-top-programming-languages-2023

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1.&nbsp;왜 개발환경 구축부터 시작해야 하나요?

# %% [markdown]
# ### ![image.png](data:image/png;base64,...)&nbsp;&nbsp;1.1. Google Colab

# %% [markdown]
# * **Colab(Colaboratory)**은 Google이 제공하는 클라우드 기반 Jupyter Notebook 개발 도구(주피터 노트북 + 구글 드라이브)
# * 고성능 컴퓨팅 리소스 활용하여 데이터 분석, 머신러닝, 딥러닝 등 작업 수행
#
# * Colab의 주요 특징(상세는 https://colab.research.google.com/ 참조)
#   * **클라우드 서버**에서 실행되므로 별도의 설치나 구성 없이 웹 브라우저에서 바로 사용할 수 있음
#     * **코드를 셀(cell) 단위로 실행하고 중간 결과를 바로 확인할 수 있어** 초보자가 Python 문법과 라이브러리 사용법을 익히거나 실험적 탐색 등에 유용(아래 코드 예시)
#     * 💡 **(참고)** 코드 실행 단계를 시각화하여 보여주는 https://pythontutor.com/ 도 함께 활용할 것을 추천
#   * **GPU**와 **TPU**를 일정 시간 동안 무료로 사용할 수 있음
#   * **Google Drive와 연동**되어 노트북과 데이터 파일을 쉽게 저장하고 공유할 수 있음
#   * 데이터 분석과 머신러닝에 널리 사용되는 `NumPy`, `Pandas`, `Matplotlib`, `TensorFlow`, `PyTorch` 등 **다양한 라이브러리** 기본 제공
#   * 여러 사용자가 동시에 편집하고 실행할 수 있는 **실시간 협업** 기능
#   * **Python 3**이 기본 런타임 유형
#     * 런타임 유형 메뉴에서 R도 선택할 수 있음
#       * `tidyverse`, `ggplot2` 등 인기 있는 R 패키지 기본 설치
#     * JavaScript 코드를 실행하거나(`%%javascript` 매직 명령어 사용),
#     * SQL 쿼리를 작성·실행하는 것도 가능
#       * `!pip install ipython-sql`로 라이브러리 설치 필요
#       * `%%sql` 매직 명령어 사용
#       * Python `pandas` 라이브러리와 연동하여 SQL 쿼리 결과를 데이터프레임으로 불러올 수 있음
#   * Bash 셸(shell) 명령어 실행 가능
#     * `!` 접두사 사용
#     * 예컨대, `!ls`는 현재 디렉토리 파일 목록 출력
#   * LaTeX로 수학 공식 작성 가능
#     * **평균 제곱 오차(Mean Squared Error, MSE):** 예측값과 실제값의 차이를 제곱하여 평균 낸 것으로, 회귀 문제에서 모델의 성능을 측정하는 데 사용
#
# $$
# \text{MSE} = \frac{1}{n} \sum_{i=1}^n (y_i - \hat{y}_i)^2
# $$

# %%
from IPython.display import HTML

video_id = "2_fnmPRwhWs"

HTML(f"""
<iframe width="560" height="315"
src="https://www.youtube.com/embed/{video_id}?autoplay=1"
frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture"
allowfullscreen></iframe>
""")

# %%
print("Hello World!")

# %%
7+2

# %%
7-2
7*2

# %%
print(7/2)
print(7//2)
print(7%2)
print(7**3)

# %%
print("안녕"+"하세요")
print(("안녕"+"하세요")*3)
print("안녕"+"하세요"*3)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 경로 설정1
# !cd /content/drive/경로  # cd: change directory, 띄어쓰기 있을 때는 '＼'를 입력하는 방법이 있기는 함

# %%
# 경로 설정2
import os

# os.chdir('/content/drive/경로')

print(os.getcwd())

# %%
# !ls

# %%
# %%javascript
# alert('Hello, World!');

# %% [markdown]
# #### [보충설명] Jupyter Notebook

# %% [markdown]
# * 전통적인 소스 코드→컴파일→실행 방식에서 벗어나 웹 기반 대화형 개발 및 실행 환경 제공
# * Python을 비롯한 40여 개 프로그래밍 언어 지원
# * **Markdown**을 이용하여 코드 관련 타이틀과 설명 등을 작성할 수 있고, 문서화하여 다른 사람과 공유하기가 편리함
#
#   * (참고) **Markdown**
#     * 2004년 John Gruber와 Aaron Swartz 개발
#     * HTML (Hypertext **Markup** Language) 같은 마크업 언어는 다양한 태그를 사용하여 웹 페이지 내용을 구조화하고 스타일을 지정하지만, 복잡하고 읽기 어려움
#     * 사용자가 서식을 지정할 때 필요한 마크업 양을 낮춘다(mark down)는 의미로, 마크업 방식보다 간단하고 직관적인 문법을 사용하여 쉽게 읽고 쓸 수 있음
#     * [GitHub Gist] ihoneymon, ["마크다운(Markdown) 사용법"](https://gist.github.com/ihoneymon/652be052a0727ad59601) (2023. 3. 13. last update)
#     * [The Markdown Guide](https://www.markdownguide.org/)

# %% [markdown]
# #### [보충설명] Colab Pro

# %% [markdown]
#  * Colab AI 자동 완성 제공
#
#  * 하드웨어 가속기(저사양순)
#    * NVIDIA GPU: T4 < V100 < L4 < A100
#    * Google TPU: TPU < TPU v2
#    * T4 < **TPU** < V100 < L4 < A100 < **TPU v2**
#
#  * **NVIDIA GPU**
#    * **T4**
#      * Turing 아키텍처 기반의 에너지 효율성을 갖춘 GPU로 멀티프리시전 지원
#      * GPU 메모리 16GB
#      * 온라인 추론, 라이브 스트리밍 처리에 이상적, 모델 학습에도 사용 가능
#      * V100보다 성능이 낮지만, 무료 Colab으로도 사용 가능
#    * V100 (**"deprecated":**, 향후 사용 중단 예정)
#      * NVIDIA의 A100 전 세대 GPU, Volta 아키텍처 기반
#      * GPU 메모리 16GB 또는 32GB
#      * 많은 딥러닝 모델 학습에 충분하고 안정적인 성능 제공
#    * L4
#      * Ampere 아키텍처 기반
#      * GPU 메모리 16GB 또는 32GB
#      * 엣지 컴퓨팅과 인공지능 추론 작업에 최적화, 높은 에너지 효율성
#    * **A100**
#      * Colab Pro에서 지원하는 NVIDIA GPU 중 최신의 것, Ampere 아키텍처 기반
#      * 40GB 대용량 GPU 메모리
#      * 대규모 머신러닝 모델 학습, 복잡한 AI 연산에 사용
#  * **Google TPU (Tensor Processing Unit)**
#      * Google에서 설계한 ASIC(Application-Specific Integrated Circuit, 특정 목적 집적 회로)
#      * 대규모 머신러닝 연산, 특히 TensorFlow와 같은 프레임워크를 사용한 딥러닝 작업에 최적화
#      * GPU와는 다른 아키텍처를 가지고 있어, TPU에 최적화된 코드를 작성해야 최고 성능을 얻을 수 있음
#      * TPU v2는 성능과 메모리 용량을 향상시킨 것으로 이전 TPU는 deprecated
#
#  * **(참고) NVIDIA H100**
#    * 서버용 GPU로, 2022년 9월에 출시(Colab에서는 제공되지 않으나, 일부 클라우드 서비스에서 제공되고 있음)
#    * Hopper 아키텍처 기반, 이전 세대인 A100보다 큰 성능 향상
#    * 80GB의 대용량 HBM3 GPU 메모리
#    * 그 밖에 NVIDA GPU에 관하여 https://resources.nvidia.com/l/en-us-gpu 참조

# %% [markdown]
# ##### (참고) NVIDIA A100 HPC Performance
# 출처: [NVIDIA](https://www.nvidia.com/en-us/data-center/a100/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### (참고) NVIDIA L4 v. A100
#
# 출처: E2E Cloud, ["NVIDIA L4 vs. A100 GPUs: Choosing the Right Option for Your AI Needs"](https://www.e2enetworks.com/blog/nvidia-l4-vs-a100-gpus-choosing-the-right-option-for-your-ai-needs) (2023. 8. 25.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.2. 개발환경 구축의 필요성

# %% [markdown]
# * 실제 머신러닝 프로젝트를 수행할 때는 Colab만으로는 한계(아래에 지적한 것 외에 세션 시간 제한, 메모리 제한, 인터넷 연결 의존도 등도 제약으로 작용할 수)
#
# * 머신러닝 프로젝트는 통상 다음과 같은 스크립트를 포함하고 이들이 소통하는 구조를 가짐(이는 절대적인 기준이 아니며, **프로젝트의 규모와 복잡성, 특성에 따라 파일 구성과 이름 등은 얼마든지 달라질 수** 있고, `models`, `data`, `utils` 등 디렉토리로 파일을 **그룹화**할 수도 있음)
#   * `model.py`: 모델의 아키텍처 정의(레이어, 활성화함수, 손실함수 등)
#   * `utils.py`: 데이터 로딩, 전처리, 증강 등 보조 기능을 포함하는 유틸리티 스크립트
#   * `dataset.py`, `dataloader.py`: PyTorch나 TensorFlow 같은 프레임워크를 사용할 때 데이터셋을 정의하고 데이터 로딩을 담당하는 파일이 별도로 존재할 수 있음
#   * `loss.py`, `metrics.py`: 손실함수나 평가지표를 사용자가 따로 정의하는 파일이 존재할 수 있음
#   * `config.yaml`, `hparam.json`: 하이퍼파라미터 등 설정
#   * `train.py`: 모델 학습을 위한 주 스크립트
#   * `test.py`, `evaluate.py`: 모델 성능 평가 위한 파일을 별도로 만들 수 있음
#   * `inference.py`, `generate.py`: 학습된 모델을 사용하여 새로운 데이터에 대해 추론을 수행하거나 결과를 생성
#
#   * 실제 사례: [YOLOv5](https://github.com/ultralytics/yolov5)
#     * (참고) **YOLO(You Only Look Once)**는 객체 인식(object detection)을 위한 딥러닝 기반의 알고리듬 중 하나로, 이미지를 한 번만 보고 그 안에 있는 여러 객체를 실시간으로 탐지하고 분류함
#
# * 여러 개 Python 스크립트 파일로 구성된 프로젝트를 효과적으로 관리하고 실행하려면 로컬 개발환경을 구축하는 것이 필수적
#
# * 로컬 개발환경의 이점:
#   * **파일과 디렉토리 구조를 체계적으로 관리**
#   * **가상환경**을 사용하여 프로젝트별로 독립적인 Python 패키지 관리
#   * **Visual Studio Code** 등 선호하는 **코드 편집기** 또는 **IDE**를 사용하여 효율적으로 코드 작성 및 디버깅
#   * 터미널 또는 명령 프롬프트에서 Python 스크립트를 직접 실행하고 파이프라인 구축(프로덕션 환경과 유사한 설정에서 코드를 실행하여 배포 전에 발생할 수 있는 오류를 사전에 발견하고 수정할 수 있음)
#   * 버전 관리 시스템(Git 등)을 사용하여 코드 변경 사항 추적 및 협업 시 코드 일관성 유지(필요시 이전 버전으로 롤백할 수 있어 유용)
#   * 데이터 보안과 프라이버시를 더 효과적으로 관리할 수 있음
#   * 필요시 로컬 환경에도 추가 하드웨어 리소스(예: GPU)를 통합하여 성능을 최적화할 수 있음
#
# 👉 머신러닝을 본격적으로 다루기 위해 개발환경을 처음부터 체계적으로 구축하는 것은 매우 중요

# %% [markdown]
# ### 1.3. 구축할 개발환경의 전체 구조

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ![image.png](data:image/png;base64,...)&nbsp;&nbsp;2. Anaconda

# %% [markdown]
# ### 2.1. 가상환경(Virtual Environment)

# %% [markdown]
# * **프로젝트별로 독립적인 개발 환경**을 만들어 주는 도구로 **특정 버전의 프로그래밍 언어, 라이브러리, 패키지 등의 집합**
#
# * 프로젝트마다 필요한 언어 버전이나 패키지가 다를 수 있음
#   * 김치찌개를 끓일 때와 김치전을 부칠 때 필요한 재료가 다르듯이,
#   * 낡은 기술이나 방법론을 사용하는 '레거시 프로젝트'에는 오래된 버전의 Python을 써야 할 수 있고, 딥러닝 프로젝트에는 `NumPy`, `PyTorch` 등 특정 패키지에 **'의존'**
#
# * **장점**
#   1. **프로젝트 간 패키지 버전 충돌 방지**
#     - 프로젝트마다 필요한 패키지와 버전을 독립적으로 관리할 수 있음
#     - 한 프로젝트에서 사용한 패키지 버전이 다른 프로젝트에 영향을 주지 않음
#
#   2. **깨끗한 환경에서 프로젝트 시작**
#     - 해당 가상환경에 필요한 패키지만 설치하므로 깨끗한 환경에서 시작할 수 있음
#     - 불필요한 패키지로 인한 문제를 방지할 수 있음
#   3. **협업 및 배포 용이**
#     - 프로젝트에 필요한 패키지 목록을 쉽게 공유할 수 있음
#     - 다른 개발자와 협업하거나 프로젝트를 배포할 때 환경 설정이 간편해짐
#
# * **종류**
#   * Python의 `venv`, Ruby의 `rvm`, Node.js의 `nvm` 등 언어별로 가상환경을 생성하는 명령어가 있는가 하면(virtual environment, Ruby / Node.js Version Manager의 약어),
#   * Docker 같은 플랫폼을 활용하여 가상환경을 구성하기도 함
#   * **Anaconda**를 사용하면 가상환경 관리가 쉽고 편리함
#
# * **의존성(dependency)**
#   * 프로젝트가 동작하는 데 필수적인 소프트웨어 구성 요소(언어 버전, 패키지, 라이브러리 등) 간의 관계
#   * 한 패키지가 다른 특정 패키지의 기능에 의존하는 경우, 두 패키지 사이에는 의존 관계 존재
#   * 프로젝트 실행과 유지보수를 위해서는 의존 관계를 고려하여 필요한 패키지를 모두 설치해야 함
#   * 복잡한 의존 관계로 인해 버전 호환성 이슈, 프로젝트 간 패키지 충돌 등이 발생할 수 있음
#   * 가상환경을 사용하면 프로젝트별로 의존성을 독립적으로 관리할 수 있어 이러한 문제 예방
#
# * **(참고 영상)** 가상환경 기초
#   * 이 강의자료에서 따로 참고하실 수 있는 여러 영상을 링크해드릴 것이나, **최신 내용을 반영하지 못한 과거 영상도 많으니 유의하시기 바랍니다**(각 영상의 업로드일을 함께 써드리겠습니다)
#   * [YouTube] 딥스푼, ["딥러닝 개발에 필요한 아나콘다 환경 설정 및 기초 사용법"](https://youtu.be/E7BpCFbWCuM?si=u975ojUH7BuVX7Et)
#   (2024. 5. 9. / 전체 28m7s)
#   * [YouTube] 나도코딩, ["파이썬 가상환경 사용 방법 (중요) | venv"](https://youtu.be/o_vKT80BBkw?si=gGSrGSlfqXx8bh9k)
#   (2022. 8. 6. / 전체 33m10s, **기초 개념에 관하여 쉽게 설명한 5m52s까지**)
#   * [YouTube] SEMONAN, ["Python Anaconda의 가상환경은 어떻게 독립적으로 작동할까? {no.3}"](https://youtu.be/_CeP5Fm4mCk?si=kp71M4QgIti1skaa)
#   (2022. 1. 5. / 전체 3m40s, **가상환경 폴더 구조**)

# %% [markdown]
# ### 2.2. 왜 Anaconda인가?

# %% [markdown]
# * 가상환경 관리, 패키지 설치, 개발환경 설정 등을 간편하게 할 수 있음
#   * 자체적인 패키지 관리자인 `conda`로 가상환경 생성, 활성화, 비활성화 가능
#     * `conda create` 가상환경 생성
#     * `conda activate` 가상환경 활성화
#     * `conda deactivate` 가상환경 비활성화
#   * `conda install` 명령어로 필요한 패키지를 쉽게 설치
#     * 패키지 의존성 관리가 쉽고, 버전 충돌을 방지할 수 있음
#     * Python 패키지 외에도, C, C++, R 등의 다양한 패키지 설치 가능
#
# * **통합개발환경(IDE; Integrated Development Environment)** 제공
#   * IDE는 코딩, 디버깅, 테스팅, 버전 관리 등 개발에 필요한 다양한 기능을 하나의 소프트웨어에서 제공하는 개발 도구
#   * Jupyter Notebook, JupyterLab, Spyder, RStudio 등의 IDE가 포함
#     * Jupyter Notebook은 웹 브라우저에서 실행되는 대화형 개발 도구로(Colab도 유사), 코드, markdown 텍스트, 그래프 등을 하나의 문서(노트북)에 통합할 수 있음
#     * JupyterLab은 Jupyter Notebook의 차세대 버전으로, 더 향상된 사용자 인터페이스와 확장성을 제공
#     * Spyder(Scientific Python Development Environment)는 Python에 특화된 IDE로, 코드 편집, 디버깅, 프로파일링 등의 기능을 제공
#     * RStudio는 R을 위한 IDE
#     * PyCharm과의 연동을 지원
#   * Anaconda를 설치하면 별도로 IDE를 설치할 필요 없이 바로 사용할 수 있어 개발환경 설정이 간편하고, 그에 드는 시간과 노력을 줄여줌
#
# * Windows, macOS, Linux 등 다양한 운영체제에서 안정적으로 작동
#
# * Anaconda Navigator라는 사용자 친화적 GUI 제공
#   * (참고 영상) Anaconda Navigator로 가상환경 설정하는 방법
#     * [YouTube] Ouk Choi, ["1.2. Anaconda 가상 환경 생성 방법"](https://youtu.be/Zd_gRGTVvFQ?si=nsPlvZEEcVngtgKN)
# (2022. 8. 5. / 전체 7m47s, 그러나 주의할 점이 있음, 후술)
#
# * 무엇보다 광범위한 사용자 기반(**"남들이 많이 쓴다!"**)
#   * 데이터 사이언스, 머신러닝 워크플로(아래 **보충설명** 참고)에 특화되어 많은 프로젝트와 연구에서 Anaconda가 사용되고 있음
#   * Anaconda를 통해 개발환경을 쉽게 공유하고 재현할 수 있어 협업과 연구 결과 공유에 유리

# %% [markdown]
# #### [보충설명] 데이터 사이언스, 머신러닝의 일반적 Workflow

# %% [markdown]
#   * **데이터 수집 및 정제(Data Collection and Cleaning):** 분석에 필요한 데이터를 수집하고, 결측치, 이상치 등을 처리하여 데이터를 정제
#
#   * **데이터 탐색 및 시각화(Data Exploration and Visualization):** 정제된 데이터를 탐색하고, 시각화를 통해 데이터의 특징과 패턴을 파악(결과물로서 시각화와 구별)
#
#   * **데이터 전처리(Data Preprocessing):** 모델링에 적합한 형태로 데이터를 변환하고 가공
#     * **피처 엔지니어링(Feature Engineering):**
#       * 새로운 정보를 추가하거나 피처를 변환
#       * 예: 범주형 변수 인코딩 / 연속형 변수의 구간화 또는 이산화 / 파생변수(eg. 거래 데이터에서 '구매빈도', '구매금액' 등 새로운 피처) 생성 / 텍스트 데이터에서 핵심 키워드 추출 또는 감성 점수 계산 등
#     * **피처 스케일링(Feature Scaling):**
#       * 기존 피처의 스케일 조정
#       * 예: 표준화(Standardization, 평균 0 분산 1) / 정규화(Normalization, 최소값 0, 최대값 1) / 로그 변환(Log Transformation, 왜곡된 분포를 가진 피처에 로그 취해 분포를 정규분포에 가깝게 만드는 방법)
#
#   * **모델링 및 알고리듬 선택(Modeling and Algorithm Selection):** 문제의 유형과 데이터의 특성에 맞는 모델과 알고리듬 선택
#
#   * **모델 학습 및 평가(Model Training and Evaluation):** 선택한 모델을 데이터로 학습시키고, 검증 데이터나 교차 검증을 통해 모델의 성능을 평가, 성능이 만족스럽지 않다면 다시 데이터 전처리 단계로 돌아가 피처 엔지니어링 등 다시 수행할 수
#
#   * **모델 배포 및 서빙(Model Deployment and Serving):** 학습된 모델을 실제 환경에 배포하고, 새로운 데이터에 대한 예측을 제공
#
#   * **(참고)** Aurélien Géron, 박해선 역, **『핸즈온 머신러닝』(2023년 9월 제3판 발행)** 제2장 등

# %% [markdown]
# ### 2.3. Anaconda 설치와 실행

# %% [markdown]
# * **설치**
#   * 공식 홈페이지에서 각자 OS에 따라 다운로드하여 설치 가능
#     * "Free Download" 페이지에서 "Skip registration"하면
#     * https://www.anaconda.com/download/success 연결(아래 2024. 5. 5. 캡쳐 화면 참조)
#   * 특별히 건드릴 필요 없이 기본 설정대로 설치

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * **실행**
#   * Windows 검색창에서 **"Anaconda Prompt"** 입력하여 실행
#     * Anaconda만 입력해도 Anaconda Prompt, Anaconda Navigator, Anaconda Powershell Prompt가 보일 것인데,
#     * 그중 첫번째 것을 클릭하여 실행한 뒤 입력창에 `conda` 입력
#     * 아래 화면과 같이 나오면 잘 설치된 것
#   * 일반적인 **커맨트 프롬프트(cmd)**에서 실행하려면 Anaconda 관련 도구들(Python 인터프리터, 패키지 관리자 conda 등)의 경로를 시스템 환경 변수에 수동으로 추가해야 하는데, Anaconda Prompt는 이를 미리 설정해 둔 것
#   * mac은 기본 터미널 창에서 바로 접근 가능
#
#
# <br/>
#
#
# >   * 💥 **(주의사항, 전혀 모르셔도 되는 내용이므로 관심 있는 분들만 재미로 보세요)** Anaconda 설치할 때 "Add Anaconda to my PATH environment variable" 옵션을 선택하면 cmd에서도 conda 명령어를 바로 사용할 수 있으나, 다음과 같은 문제가 발생
#     * **버전 충돌 가능성:** 시스템 PATH에 Anaconda 경로를 추가하면, Anaconda의 Python이 시스템 기본 Python보다 우선적으로 인식되어 다른 응용 프로그램에서 의도치 않게 Anaconda의 Python을 사용하게 될 수 있고, 이는 버전 호환성 문제를 일으킬 수 있음
#     * **보안 문제:** PATH에 Anaconda 경로를 추가하면, 악의적인 사용자가 Anaconda 디렉토리에 악성 스크립트를 삽입했을 때, 시스템 전체에 영향을 줄 수 있는 보안 문제가 발생할 수 있음
#     * **유지 보수 및 관리의 어려움:** PATH에 Anaconda 경로를 추가하면, 시스템 전역에 영향을 주기 때문에, Anaconda를 업데이트하거나 제거할 때 PATH 설정을 별도로 관리해야 하는 번거로움이 있음
#     * **Anaconda의 가상환경 시스템과 충돌 가능성:** Anaconda는 가상 환경을 통해 프로젝트별로 독립적인 Python 환경을 관리하는 것을 권장하는데, PATH에 Anaconda 경로를 추가하면, 가상환경을 사용할 때 예기치 않은 동작이 발생할 수 있음
#     * 따라서 설치 화면에 나오는 것처럼 **NOT recommended** (대문자 NOT)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.4. 기본 명령어
# (그러나 아직/굳이/자세히 모르셔도 됨)

# %% [markdown]
#   * 공식 Conda Cheat Sheet https://docs.conda.io/projects/conda/en/4.6.0/_downloads/52a95608c49671267e40c689e0bc00ca/conda-cheatsheet.pdf (필요할 때 검색하거나 AI assistant에 물어서 하면 되고 다 알 필요가 전혀 없음)
#
#   * 소괄호 안의 글자 (base)는 지금 활성화되어 있는 환경을 가리킴
#     * **일반적으로는 base 환경은 그대로 두고, 여기에 다른 패키지를 설치하지 않기를 권장!**
#     * **base 환경을 깨끗하게 유지하고 프로젝트별로 독립적인 가상 환경을 사용하는 것이 Anaconda를 통해 가상환경을 구축하는 주요 목적 중 하나!**
#     * 그러나 앞서 본 [YouTube] Ouk Choi, ["1.2. Anaconda 가상 환경 생성 방법"](https://youtu.be/Zd_gRGTVvFQ?si=ARhSEreCYg9DTNB6&t=124)
# (2022. 8. 5. / 2분 4초 무렵)은, 가상환경 개념에 익숙하지 않은 초보자나 가상환경 관리가 귀찮은 사람들은 base 환경을 사용해도 무방하다는 식으로 설명하고 있기는 함(작은 프로젝트나 실험용으로는 base 환경이 무방할 것)

# %% [markdown]
# #### 2.4.1. 가상환경 만들기

# %% [markdown]
# * **가상환경 생성**
#   * `conda create -n [가상환경 이름] python=[사용하고자 하는 Python 버전]`
#
# * **가상환경 활성화**
#   * `conda activate [가상환경 이름]`
#
# * 현재 **가상환경 비활성화**(base로 복귀)
#   * `conda deactivate`
#
# * **<실습>**
#   * `conda create -n jucos39 python=3.9`
#   * `conda activate jucos39`
#   * `conda deactivate`

# %% [markdown]
# * 가상환경 이름 설정, Python 버전 선택
#
# * Python은 기본적으로 최신 버전의 것이 좋으나, 다음과 같은 이유로 머신러닝 프로젝트에서는 **한두 단계 이전의 안정화된 버전**을 선택하는 것이 일반적
#   1. **라이브러리 호환성:** 일부 머신러닝 라이브러리들은 최신 Python 버전에 대한 지원이 늦어질 수 있어 안정화된 버전의 Python을 사용하면 라이브러리 호환성 문제를 피할 수 있음
#   2. **안정성:** 최신 버전의 Python은 새로운 기능과 변경사항을 포함하고 있어 예기치 않은 버그나 호환성 문제가 발생할 가능성이 더 높은 반면 약간 오래된 버전은 널리 사용되고 테스트되어 더 안정적일 수 있으며 커뮤니티에서도 잘 지원
#   3. **학습 자료와의 일관성:** 많은 머신러닝 튜토리얼, 강좌, 책 등이 특정 Python 버전을 기준으로 작성되므로, 해당 버전과 유사한 Python 버전을 사용하면 학습 자료를 따라하기 더 수월함
#
# * 2024년 5월 현재 Python의 최신 버전은 2023년 10월 2일에 나온 Python 3.12
#   * 버전 정보는 다운로드 사이트 참고(https://www.python.org/downloads/)
#   * [PEP693](https://peps.python.org/pep-0693/)
#   * **(참고) PEP(Python Enhancement Proposal, 파이썬 개선 제안서)**
#     * Python 언어나 표준 라이브러리에 새로운 기능을 추가하거나 기존 기능을 변경하기 위한 제안 / Python 개발 프로세스, 도구, 환경 등의 개선을 위한 제안 / Python 커뮤니티의 가이드라인, 규약, 정보 등을 포함
#     * 일련번호와 제목을 포함한 각 PEP는 해당 제안의 배경, 동기, 설명, 구현 방법 등을 자세히 기술, 대표적인 PEP로는 [PEP 8(Style Guide for Python Code)](https://peps.python.org/pep-0008/), [PEP 20(The Zen of Python)](https://peps.python.org/pep-0020/), [PEP 484(Type Hints)](https://peps.python.org/pep-0484/) 등이 있음
#     * Python 커뮤니티의 검토와 논의를 거쳐 수정되고 보완되며, 최종적으로 승인되거나 거부되기도 함
#     * Python 커뮤니티는 PEP를 통해 언어의 발전 방향을 논의하고, Python 프로그래밍 언어의 표준을 설정하는데, 이러한 시스템은 Python의 개방성과 협업적 개발 프로세스를 반영
#
# * 우리 공부 목적에는 **Python 3.9** 정도면 무난할 것으로 보임
#   * 2020년 10월 릴리스되어 충분히 최신 버전이며, 2024년 현재 안정성과 호환성이 검증된 버전
#   * 각 Python 버전은 공식적으로 지원 종료일이 있는데, Python 3.9는 2025년 10월까지 보안 패치와 업데이트가 제공되므로 2024년에 사용하는 것은 여전히 안전
#   * 많은 머신러닝 및 데이터 사이언스 라이브러리들이 Python 3.9에서 잘 작동하며, 관련 커뮤니티에서도 광범위하게 사용
#   * Python 3.9를 지원하지 않는 특정한 라이브러리나 프레임워크를 사용하게 되었을 때는 새로운 가상환경을 설정하면 됨
#
# * 2024년 5월 현재 conda 최신 버전은 24.4.0

# %% [markdown]
# #### 2.4.2. 가상환경 관리

# %% [markdown]
# * 내 컴퓨터 **가상환경 목록 보기**
#   * `conda env list`
#   * env는 environment를 의미
#
# * **가상환경 삭제**
#   * `conda env remove -n [가상환경 이름]`
#
# * **<실습>**
#   * `conda env list`

# %% [markdown]
# #### 2.4.3. 패키지 설치 및 관리

# %% [markdown]
# * `conda` 또는 `pip` 두 가지 방법을 중 하나를 선택하여 원하는 패키지 설치
#
# <br/>
#
# * 설치된 **패키지 목록 보기**
#   * `conda list`
#   * `pip list`
#
# * **패키지 설치**
#   * `conda install [패키지 이름]`
#   * 기본 채널 외에 특정한 사용자나 조직이 만든 채널에서 제공하는 패키지를 설치할 때는
#   `conda install -c [채널 이름] [패키지 이름]`
#   * Anaconda가 제공하는 기본 채널(conda-forge 등)에는 대부분의 주요 패키지들이 포함되어 있음
#   * `pip install [패키지 이름]`
#
# * **패키지 삭제**
#   * `conda remove [패키지 이름]`
#   * `pip uninstall [패키지 이름]`
#
# * **<실습>**
#   * `conda list`
#   * `pip list`
#   * `pip install numpy`
#   * `conda list`
#   * `pip list`
#   * `pip uninstall numpy`
#   * `conda install numpy`
#   * `conda install pytorch`

# %% [markdown]
# ##### [보충설명] conda와 pip
# (전혀 모르셔도 되는 내용이므로 관심 있는 분들만 재미로 보세요)

# %% [markdown]
#   * **conda**
#     * Anaconda의 기본 패키지 관리자
#
#     * **장점**
#       * conda는 Python 패키지뿐만 아니라 **다른 언어(C, C++, R, Ruby 등)**의 패키지도 관리할 수 있어 Python 외의 패키지와 호환성이 필요할 때 유리
#       * conda는 패키지를 설치할 때 해당 패키지가 의존하는 다른 패키지들의 호환 가능한 버전을 자동으로 선택하고 설치하므로 **패키지 의존성을 효과적으로 관리**해주고 충돌 최소화
#       * 강력한 가상환경 관리 기능 제공
#     * **단점**
#       * conda 패키지는 Anaconda repository에 의존하여 PyPI(Python Package Index)에 있는 모든 Python 패키지가 conda 패키지로 제공되는 것은 아니고, 최신 버전 패키지를 사용할 수 없는 경우도 있음
#       * (특히 복잡한 의존성 구조를 가졌을 때) conda의 패키지 해석 과정이 pip보다 느릴 수 있음
#
#   * **pip(Package Installer for Python)**
#     * Python 패키지 설치를 위한 표준 패키지 관리자
#
#     * **장점**
#       * **PyPI(Python Package Index)**에서 직접 패키지를 설치하므로 거의 모든 Python 패키지를 설치할 수 있고, 종종 conda보다 빠르게 최신 버전 제공
#       * (특히 간단한 의존성 구조를 가졌을 때) 패키지 설치가 conda보다 빠를 수 있음
#       * 사용법이 간단하고 명령어 구조가 직관적
#     * **단점**
#       * Python 패키지만 설치할 수 있음
#       * conda보다 패키지 의존성 충돌이 발생할 가능성이 더 높고, 이를 수동으로 해결해야 할 때가 있음
#       * conda처럼 자체적으로 가상환경을 생성하고 관리하는 기능은 제공하지 않고 대신 `venv`(Python 3.3부터 기본 모듈에 포함) 또는 `virtualenv`(Python 2부터 쓰인 가상환경 라이브러리) 같은 도구를 사용해야
#
#   * **결론**
#     * 일반적으로 Anaconda 가상환경에서는 패키지 간 의존성을 잘 처리하고 다양한 언어의 패키지를 설치할 수 있는 conda로 패키지를 설치하는 것이 좋음
#     * 특히 NumPy, SciPy, Pandas, Matplotlib 등 주요 과학 계산 및 데이터 분석 패키지들은 conda를 통해 설치하는 것이 안정적
#     * 필요한 패키지가 conda 채널에서 제공되지 않는 경우에 pip 사용
#
# * **(참고 영상)** conda와 pip 비교 더 상세한 설명
#   * [YouTube] 도움코드 쉬운예 DoumCode 데이터홍교수, ["conda와 pip 차이 뭘까요? 채널 무엇일까요? | 파이썬 패키지 빠른 재설치, conda-pack 1화"](https://youtu.be/HCIJC0jnMEQ?si=t5LP4Vnxmb-Zsi1s) (2020. 11. 5. / 전체 18m27s)

# %% [markdown]
# #### 2.4.4. (참고) 가상환경 재현과 공유

# %% [markdown]
# * Github에 공유된 머신러닝 코드를 재현하기 위해 conda 환경을 함께 받아야 하는 경우가 있음
#   * 예컨대, [Stable Diffusion](https://github.com/CompVis/stable-diffusion?tab=readme-ov-file)
#
# * YAML 파일로 가상환경 생성
#   * `conda env create -f [YAML 파일명]`
#
# * 내 가상환경 YAML 파일로 내보내기
#   * `conda	env	export >	[YAML 파일명(.yml 또는 .yaml)]`
#
# * (참고) YAML (전혀 모르셔도 되는 내용이므로 관심 있는 분들만 재미로 보세요)
#   * YAML은 "YAML Ain't Markup Language"의 재귀적 약어로, 원래는 "Yet Another Markup Language"의 약어였지만, 이제 마크업 언어보다 데이터 직렬화 포맷으로 더 많이 사용되기 때문에 이름이 바뀜
#   * 다양한 프로그래밍 언어에서 데이터 구조를 나타내는 데 사용되며, 설정 파일, 데이터 교환 등에 활용(Anaconda에서도 가상환경을 정의하고 공유하는 데 활용)
#   * JSON과 함께 가장 널리 사용되는 데이터 직렬화 포맷 중 하나로, 간단하고 직관적인 구문을 사용하여 데이터를 사람이 읽고 쓰기 쉬운 형태로 표현하는 데 초점
#   * DevOps, 클라우드 컴퓨팅, 데이터 분석 등 분야에서 중요한 역할

# %% [markdown]
# #### **(참고 영상)** Anaconda 기본 명령어 소개
#   * 과거 영상을 볼 때는 유의
#   * [YouTube] 레이원TV, [아나콘다(Anaconda) 사용법 및 가상환경 관리하는법](https://youtu.be/hz6KIvPBW4U?si=DLg5GPG4tj0GCOBA) (2019. 12. 30. / 전체 17m23s)
#   * [YouTube] 보안프로젝트, ["아나콘다 파이썬 콘솔 기본 명령어 배우기"](https://youtu.be/7LSzg5Fzc88?si=zVIXn_rrsm702dSK)
#   (2020. 11. 21. / 전체 12m26s)
#   * [YouTube] 나도코딩, ["파이썬 가상환경 사용 방법 (중요) | venv"](https://youtu.be/o_vKT80BBkw?si=gGSrGSlfqXx8bh9k)
#   (2022. 8. 6. / 전체 33m10s, **pip, VSCode 사용**)

# %% [markdown]
# ## ![image.png](data:image/png;base64,...)&nbsp;&nbsp;3. Visual Studio Code

# %% [markdown]
# ### 3.1. Visual Studio Code (VS Code) 소개

# %% [markdown]
# * Microsoft에서 개발한 경량화된 오픈 소스 코드 편집기
# ⚠️ 대규모 프로젝트 개발에 사용되는 Visual Studio와는 별개
#
# * **강점**
#   1. Python, C, C++, Java, JavaScript 등 다양한 프로그래밍 언어 지원
#   2. 다양한 Extension(확장 기능, 플러그인) 지원
#   3. 편리한 개인화(환경설정, 단축키 등)
#   4. 파일 탐색기 통합, 내장 터미널을 통해 에디터 내에서 직접 명령 실행 가능
#   5. 다양한 언어와 프레임워크에 대한 강력한 디버깅 기능으로 코드 오류를 쉽게 찾고 수정할 수 있음
#   6. 내장된 Git 지원으로 코드 변경 사항 추적, 커밋 및 브랜치 관리를 직접 할 수 있어 Git 버전 관리 수월
#   7. (참고) SSH(Secure Shell)를 통한 원격 서버 작업, WSL(Windows Subsystem for Linux)을 통한 Windows에서의 Linux 환경 개발, Docker 컨테이너와의 통합 등 일관된 개발환경 구축 가능

# %% [markdown]
# * Stack Overflow 설문조사에 따르면,
#   * 2016년까지만 해도 가장 많이 쓰이는 개발 툴이 Notepad++였고 VS Code는 10위권 밖이었으나(Visual Studio가 2위),
#   * 2017년 5위로 도약한 후
#   * 2018년 이래 굳건히 1위를 지키면서 선호율이 날로 증가하고 있음(아래 참조)

# %% [markdown]
# Stack Overflow 2023 Developer Survey 중 [IDE](https://survey.stackoverflow.co/2023/#section-most-popular-technologies-integrated-development-environment) 부분 발췌
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.2. VS Code 설치

# %% [markdown]
# * **설치**
#   * 공식 홈페이지에서 각자 OS에 따라 다운로드하여 설치 가능
#     * https://code.visualstudio.com/download
#   * 특별히 건드릴 필요 없이 기본 설정대로 설치
#     * "바탕화면에 바로가기 만들기": 취향 따라 선택해도 무방
#     * "(VS) Code를 지원되는 파일 형식에 대한 편집기로 등록합니다(Register Code as an editor for supported file types)": **선택**
#     * "PATH에 추가(다시 시작한 후 사용 가능)": **선택**
#     * 나머지도 선택해도 무방
#
# * VS Code 실행하여 **Extension** 설치
#   * 확장은 ![image.png](data:image/png;base64,...) 클릭 또는 Ctrl + Shift + X
#   * **한국어 언어 팩**(제공자 Microsoft / microsoft.com 확인): 자동으로 메시지 뜨면 설치하면 되고 다시 시작
#   * **Python Extension**(제공자 Microsoft / microsoft.com 확인)
#   * 나머지는 수시로 추가

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **(참고 영상) VS Code 설치**
#   * [YouTube] 프로그래머 김플 스튜디오, [VS Code 설치와 실행, 기본 사용방법, 익스텐션(확장 프로그램) 설치](https://youtu.be/vesxpfOAOCw?si=19eyyICc87aWJr4Q) (2023. 4. 13. / 전체 7m45s)
#   * [YouTube] 스타트코딩, [코딩 자격증 따기 3강 : 환경설정 - 파이썬 설치 및 VSCODE 사용법](https://youtu.be/NfR_jPZDIwE?si=9XnhaJ4nP0VLbSgH)
#   (2022. 12. 15. / 전체 16m29s, **주: Anaconda로 python을 포함한 가상환경을 생성했다면 이 영상에서 설명하는 것과 같은 별도의 Python 설치가 불필요하기는 하나, 설치해 두면 다른 쓸모가 있기는 함**)

# %% [markdown]
# #### **(참고 영상) 실력이 좀 쌓인 뒤에 보면 유용한 영상**
#   * [YouTube] 프로그래머 김플 스튜디오, [vscode 사용법, 단축키 / 비주얼 스튜디오 코드(Visual Studio Code) / 프로그래밍 초보자 코딩속도 올리기](https://youtu.be/D9n45RlSCOc?si=P9YUXnGF0mZ-A5m2) (2022. 10. 20. / 전체 12m54s)
#   * [YouTube] 드림코딩, [비쥬얼 스튜디오 코드 필수 단축키 정리 (Visual Studio Code 꿀템🍯🐝 )](https://youtu.be/EVxCdenPbFs?si=yn9hfsThMq88mqkZ) (2020. 12. 28. / 전체 7m50s)
#   * [YouTube] 드림코딩, [비쥬얼 스튜디오 코드 신규 기능 + 필수 익스텐션 추천](https://youtu.be/XMfyfNZooi4?si=jAHHl9Wk-eQHugAG)
#   (2022. 12. 6. / 전체 9m27s)

# %% [markdown]
# ### 3.3. VS Code에서 conda 가상환경 활용

# %% [markdown]
# * 특정한 파이썬 파일(.py)이 열려 있는 상태에서
# * F1 (또는 Ctrl+Shift+P 또는 "검색" 창에서 ">") > "Python: 인터프리터 선택" 입력 > 원하는 conda 환경(eg. jucos39) 선택하여 연결
#
# </br>
#
# * 내장 터미널에서 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ![image.png](data:image/png;base64,...)&nbsp;![image.png](data:image/png;base64,...)&nbsp;&nbsp;4. Google Colab x Google Drive

# %% [markdown]
# ### 4.1. 구축할 개발환경의 전체 구조

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 🤔 어떻게 Colab의 고성능 하드웨어를 개인용 GPU처럼 쓸 것인가?

# %% [markdown]
# ### 4.2. 데스크톱용 Google Drive 설치

# %% [markdown]
# * 구글에서 제공하는 클라우드 스토리지 및 파일 동기화 서비스(**Backup and Sync**)
#
# * 데스크톱 앱을 설치하면 로컬 컴퓨터에 **구글 드라이브 폴더**가 생성되고, 폴더 내 파일을 저장하거나 편집하면 변경사항이 자동으로 클라우드에 동기화되어 다른 장치에서도 접근 가능(클라우드 변경사항도 로컬 폴더에 실시간 반영됨)
#
# * VS Code, Colab 등 개발도구와 함께 사용할 때 더욱 효과적
#
# * **장점**
#  * **로컬 작업 환경과 통합:** 데스크톱 앱을 사용하면 익숙한 로컬 작업 환경에서 직접 파일을 관리할 수 있어 편리
#  * **실시간 동기화:** 변경사항이 실시간으로 동기화되므로다른 기기에서 작업할 때도 항상 최신 버전의 파일을 사용할 수 있음
#  * **오프라인 액세스:** 데스크톱 앱을 사용하면 인터넷 연결이 없는 상태에서도 로컬에 동기화된 파일에 액세스할 수 있음
#  * **선택적 동기화:** 필요한 폴더만 선택하여 로컬 컴퓨터에 동기화하는 방식으로 저장공간을 효율적으로 관리할 수 있음
#  * **파일 공유 및 협업:** 데스크톱 앱에서도 파일을 공유하고 협업할 수 있어 팀 작업이 수월
#
# * **설치**
#   * 각자 OS에 따라 다운로드하여 설치
#   * 한글 페이지 https://support.google.com/a/users/answer/13022292?hl=ko
#     영문 페이지 https://support.google.com/a/users/answer/13022292?hl=en
#   * 다운로드한 파일을 실행하여 설치 후 구글 계정으로 로그인하면 컴퓨터에 **구글 드라이브 폴더**가 생성되고 동기화 시작
#   * 환경설정에서 동기화 옵션, 프록시 설정 등을 조정할 수 있음

# %% [markdown]
# #### **(참고 영상) 데스크톱용 Google Drive 설치**
# * [YouTube] 딥스푼, ["Colab GPU의 응용 활용법 : Colab의 GPU를 개인 GPU처럼 사용해 편하게 딥러닝 학습하기"](https://youtu.be/3F6hmLw_UIk?si=gzJtQdfKev_rX68f)
#   (2024. 5. 12. / 전체 25m42s)
# * [YouTube] MegazoneSoft, ["[코로나 시대 "Google Workspace 1분 꿀팁"] Google Drive - 데스크톱용 Drive 설치"](https://youtu.be/brdf0G0IGUI?si=Q5eQjRPaSsbmRzEj) (2021. 6. 14. / 전체 1m48s)

# %% [markdown]
# ### 4.3. Google Drive 마운트

# %% [markdown]
# * Colab 공식 페이지 설명 https://colab.research.google.com/notebooks/io.ipynb
#
# * 실습
#   * VS Code에서 Colab로
#   * Colab에서 VS Code로
#   * Colab에서 Python 파일 실행

# %%
# !python 파일명.py  # Python이 구동되고 있는 환경(Colab) 안에서 또 다른 Python 파일이 실행되는 것이라고 생각할 수 있음(느낌표 '!' 필요)

# %% [markdown]
# * 🚩 **주의사항**
#   * 개발할 때는 로컬 자원 사용
#     * Colab은 사용 시간과 자원 등에 제한
#     * 연결이 끊기거나 불안정할 수 있음
#     * 중요한 개발 작업은 로컬 환경에서 수행하는 것이 안전
#   * 개발환경과 실제 운영환경을 되도록 유사하게 구성
#     * Colab은 지속적으로 업데이트되므로, 새로운 버전에서 코드 호환성 문제가 발생할 수 있음
#     * 업데이트 내용 확인하여 필요한 조치 취해야
#   * 개인정보보호 및 보안에 유의
#     * 공유 시 접근권한 적절히 설정
#     * 민감한 정보가 포함된 문서는 신중하게 관리하고 불필요한 공유 회피
#     * 의심스러운 파일이나 링크를 받았을 때는 반드시 확인 후 열람
#     * 공용 컴퓨터에서 구글 드라이브 접속 시 반드시 로그아웃
#     * 2단계 인증 설정으로 계정 보안 강화
#   * 저장공간 관리
#     * 대용량 파일을 다수 저장하면 할당된 용량을 초과할 수 있으므로 주기적으로 불필요한 파일 정리
#     * 자주 쓰지 않는 파일은 클라우드에만 저장하여 로컬 저장공간 절약
#   * 파일 동기화 관련 이슈
#     * 동기화 오류, 충돌이 발생할 수 있음
#     * 중요한 데이터는 소실 방지를 위해 별도의 백업 계획 수립
